# %% [markdown]
# ### Title: NYC Restaurant Inspection Results Analysis
# ### Dataset: DOHMH New York City Restaurant Inspection Results
# This notebook performs an exploratory analysis of a NYC restaurant inspection dataset.

# %%
import pandas as pd

df = pd.read_csv('DOHMH_New_York_City_Restaurant_Inspection_Results_20260426.csv')
print("Dataset loaded successfully with " + str(len(df)) + " rows.")
# Out:
# C:\Users\flipp\AppData\Local\Temp\ipykernel_3060\769630978.py:3: DtypeWarning: Columns (0: PHONE) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('DOHMH_New_York_City_Restaurant_Inspection_Results_20260426.csv')
# Dataset loaded successfully with 296352 rows.

# %% [markdown]
# ### Dataset Shape

# %%
df.shape
# Out:
# (296352, 27)

# %% [markdown]
# ### Column Names

# %%
df.columns
# Out:
# Index(['CAMIS', 'DBA', 'BORO', 'BUILDING', 'STREET', 'ZIPCODE', 'PHONE',
#        'CUISINE DESCRIPTION', 'INSPECTION DATE', 'ACTION', 'VIOLATION CODE',
#        'VIOLATION DESCRIPTION', 'CRITICAL FLAG', 'SCORE', 'GRADE',
#        'GRADE DATE', 'RECORD DATE', 'INSPECTION TYPE', 'Latitude', 'Longitude',
#        'Community Board', 'Council District', 'Census Tract', 'BIN', 'BBL',
#        'NTA', 'Location'],
#       dtype='str')

# %% [markdown]
# ### Data Types

# %%
df.dtypes
# Out:
# CAMIS                      int64
# DBA                          str
# BORO                         str
# BUILDING                     str
# STREET                       str
# ZIPCODE                  float64
# PHONE                     object
# CUISINE DESCRIPTION          str
# INSPECTION DATE              str
# ACTION                       str
# VIOLATION CODE               str
# VIOLATION DESCRIPTION        str
# CRITICAL FLAG                str
# SCORE                    float64
# GRADE                        str
# GRADE DATE                   str
# RECORD DATE                  str
# INSPECTION TYPE              str
# Latitude                 float64
# Longitude                float64
# Community Board          float64
# Council District         float64
# Census Tract             float64
# BIN                      float64
# BBL                      float64
# NTA                          str
# Location                     str
# dtype: object

# %% [markdown]
# ### Dataset Info

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 296352 entries, 0 to 296351
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   CAMIS                  296352 non-null  int64
#  1   DBA                    296349 non-null  str
#  2   BORO                   296352 non-null  str
#  3   BUILDING               295368 non-null  str
#  4   STREET                 296338 non-null  str
#  5   ZIPCODE                293182 non-null  float64
#  6   PHONE                  296272 non-null  object
#  7   CUISINE DESCRIPTION    292779 non-null  str
#  8   INSPECTION DATE        296352 non-null  str
#  9   ACTION                 292875 non-null  str
#  10  VIOLATION CODE         290520 non-null  str
#  11  VIOLATION DESCRIPTION  290520 non-null  str
#  12  CRITICAL FLAG          296352 non-null  str
#  13  SCORE                  279350 non-null  float64
#  14  GRADE                  145959 non-null  str
# ...

# %% [markdown]
# ### Description of Dataset

# %%
df.describe()
# Out:
#               CAMIS        ZIPCODE          SCORE       Latitude  \
# count  2.963520e+05  293182.000000  279350.000000  294744.000000
# mean   4.811657e+07   10705.806721      25.321725      40.295928
# std    3.720583e+06     617.089524      18.988082       4.175286
# min    3.007544e+07    6605.000000       0.000000       0.000000
# 25%    5.000628e+07   10023.000000      12.000000      40.687066
# 50%    5.009510e+07   11101.000000      21.000000      40.732937
# 75%    5.013147e+07   11232.000000      33.000000      40.761172
# max    5.018523e+07   69361.000000     214.000000      40.912822
#
#            Longitude  Community Board  Council District   Census Tract  \
# count  294744.000000    291614.000000     291644.000000  291644.000000
# mean      -73.155039       254.620224         20.511346   29854.260921
# std         7.579394       130.360772         15.651061   31248.107036
# min       -74.249101       101.000000          1.000000     100.000000
# ...

# %% [markdown]
# ### Data Samples

# %%
df.head()
# Out:
#       CAMIS                              DBA       BORO BUILDING  \
# 0  50173490                 MTSKHETA-USA INC   Brooklyn     2812
# 1  50179033                 AVE J PIZZA INC.   Brooklyn     1312
# 2  50177211                   JOEY BATS CAFE  Manhattan      151
# 3  50171910                   CORNER OF 75TH     Queens    75-01
# 4  50184429  CHEERS SMOOTHIES AND JUICES LLC      Bronx      236
#
#                STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 0        OCEAN AVENUE  11229.0  7186761868                 NaN
# 1            AVENUE J  11230.0  7326104604                 NaN
# 2    WEST   34 STREET  10001.0  9176152361                 NaN
# 3           88 STREET  11385.0  6462012666                 NaN
# 4  EAST GUN HILL ROAD  10467.0  3478121116                 NaN
#
#   INSPECTION DATE ACTION  ... INSPECTION TYPE   Latitude  Longitude  \
# 0      01/01/1900    NaN  ...             NaN  40.593064 -73.950224
# ...

# %%
df.tail()
# Out:
#            CAMIS                               DBA       BORO BUILDING  \
# 296347  50120994  RUYI LANZHOU NOODLE & BUBBLE TEA     Queens   41-10A
# 296348  50112012                    PARIS BAGUETTE     Queens   249-14
# 296349  50108675                     ROCCO'S PIZZA  Manhattan      148
# 296350  50111394                         CHACHAWAN     Queens      881
# 296351  50131016                       VIA TOSCANA  Manhattan      344
#
#                            STREET  ZIPCODE       PHONE  \
# 296347                MAIN STREET  11355.0  9175258818
# 296348  HORACE HARDING EXPRESSWAY  11362.0  3475027149
# 296349                   8 AVENUE  10011.0  9175974030
# 296350            WOODWARD AVENUE  11385.0  6462078989
# 296351           WEST   52 STREET  10019.0  6462706179
#
#              CUISINE DESCRIPTION INSPECTION DATE  \
# 296347                   Chinese      10/17/2025
# 296348  Bakery Products/Desserts      02/18/2026
# 296349                     Pizza      03/30/2026
# ...

# %%
df.sample(5)
# Out:
#            CAMIS                DBA           BORO BUILDING            STREET  \
# 160717  50004698     ROSEBANK PIZZA  Staten Island     1372        BAY STREET
# 240710  50118536  PARIS OVEN BAKERY         Queens    40-06         34 AVENUE
# 229965  50139886                TAQ      Manhattan       81     WARREN STREET
# 190186  50161246      SUSHI COUNTER      Manhattan      521  EAST   12 STREET
# 58548   50130367    TWO BOOTS PIZZA      Manhattan     1243          2 AVENUE
#
#         ZIPCODE       PHONE       CUISINE DESCRIPTION INSPECTION DATE  \
# 160717  10305.0  7184475300                     Pizza      05/07/2024
# 240710  11101.0  3475381240  Bakery Products/Desserts      06/30/2025
# 229965  10007.0  7342248188                   Tex-Mex      09/22/2025
# 190186  10009.0  6469516415                  Japanese      04/08/2025
# 58548   10065.0  6468376015                     Pizza      03/27/2023
#
#                                                  ACTION  ...  \
# ...
